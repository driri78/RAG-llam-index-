# %%
from app.core.embedding import load_rag_index

index = load_rag_index()

q = "사업관리자 초기 설정 방법"
retriever = index.as_retriever()
results = retriever.retrieve(q)

for r in results:
    print(r.node.text[:200])
# Out:
# hello world!
